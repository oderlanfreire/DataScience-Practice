# %% [markdown]
# # WEATHER

# %%
#importação de bibliotecas
import pandas as pd
import seaborn as snr
import statistics as sts

# %%
df = pd.read_csv('../data/tempo.csv', sep=';')
df.head()
# Out:
#   Aparencia  Temperatura  Umidade       Vento Jogar
# 0       sol           85     85.0       FALSO   nao
# 1       sol           80     90.0  VERDADEIRO   nao
# 2   nublado           83     86.0       FALSO   sim
# 3     chuva           70      NaN       FALSO   sim
# 4     chuva           68     80.0       FALSO   sim

# %%
df.shape
# Out:
# (14, 5)

# %% [markdown]
# ## Analise Exploratoria

# %% [markdown]
# analise exploratoria para verficação de dados

# %% [markdown]
# Dados categóricos:
# - Aparencia
# - Vento
# - Jogar
#
# Dados numéricos:
# - Temperatura
# - Umidade

# %%
group = df.groupby(["Aparencia"]).size()
group
# Out:
# Aparencia
# chuva      5
# menos      1
# nublado    3
# sol        5
# dtype: int64

# %%
group.plot.bar(color='gray')
# Out:
# <Axes: xlabel='Aparencia'>

# %%
group = df.groupby(["Vento"]).size()
group
# Out:
# Vento
# FALSO         7
# VERDADEIRO    6
# dtype: int64

# %%
group.plot.bar(color="gray")
# Out:
# <Axes: xlabel='Vento'>

# %%
group = df.groupby(['Jogar']).size()
group
# Out:
# Jogar
# nao    5
# sim    9
# dtype: int64

# %%
group.plot.bar(color='gray')
# Out:
# <Axes: xlabel='Jogar'>

# %%
group = df.groupby(["Aparencia", "Jogar"]).size()
group
# Out:
# Aparencia  Jogar
# chuva      nao      2
#            sim      3
# menos      sim      1
# nublado    sim      3
# sol        nao      3
#            sim      2
# dtype: int64

# %%
group.plot.bar(color='gray')
# Out:
# <Axes: xlabel='Aparencia,Jogar'>

# %%
group = df.groupby(['Vento','Jogar']).size()
group
# Out:
# Vento       Jogar
# FALSO       nao      2
#             sim      5
# VERDADEIRO  nao      3
#             sim      3
# dtype: int64

# %%
group.plot.bar(color="gray")
# Out:
# <Axes: xlabel='Vento,Jogar'>

# %% [markdown]
# colunas numericas

# %%
df["Temperatura"].describe()
# Out:
# count      14.000000
# mean      155.571429
# std       306.433759
# min        64.000000
# 25%        69.250000
# 50%        73.500000
# 75%        80.750000
# max      1220.000000
# Name: Temperatura, dtype: float64

# %% [markdown]
# a diferença entre a media e mediana indica apresentação de outliers

# %%
snr.boxplot(df["Temperatura"]).set_title("Temperatura")
# Out:
# Text(0.5, 1.0, 'Temperatura')

# %%
snr.histplot(df["Temperatura"], kde=True).set_title("Temperatura")
# Out:
# Text(0.5, 1.0, 'Temperatura')

# %%
df["Umidade"].describe()
# Out:
# count     13.000000
# mean      89.769231
# std       34.540203
# min       65.000000
# 25%       70.000000
# 50%       85.000000
# 75%       90.000000
# max      200.000000
# Name: Umidade, dtype: float64

# %% [markdown]
# a media e a mediana estão bem proximas

# %%
snr.boxplot(df["Umidade"]).set_title("Umidade")
# Out:
# Text(0.5, 1.0, 'Umidade')

# %%
snr.histplot(df["Umidade"]).set_title("Umidade")
# Out:
# Text(0.5, 1.0, 'Umidade')

# %% [markdown]
# foram encontrados outliers em temperatura e umidade

# %% [markdown]
# ## Tratamento
